# %%
import cv2
import numpy as np
import torch
from transformers import AutoImageProcessor
from transformers import AutoModelForObjectDetection
from transformers import pipeline
from PIL import Image, ImageDraw

# %%
url = "./detr_licence/4.png"
image = Image.open(url).convert('RGB')

image_processor = AutoImageProcessor.from_pretrained("./detr-resnet-50_finetuned_licence/checkpoint-400")
model = AutoModelForObjectDetection.from_pretrained("./detr-resnet-50_finetuned_licence/checkpoint-400")
obj_detector = pipeline(task="object-detection", model="./detr_new_data")
result = obj_detector(image)

# %%
result
# Out:
# [{'score': 0.9740789532661438,
#   'label': 'license_plate',
#   'box': {'xmin': 88, 'ymin': 164, 'xmax': 205, 'ymax': 190}}]

# %%
yellow = (0, 255, 255) # in BGR 
font = cv2.FONT_HERSHEY_SIMPLEX
stroke = 2

# Path to the video file
video_path = 'TEST.mp4'

# Open the video
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Read and display frames in a loop
while True:
    (ret, frame) = cap.read()  # Read a frame
    if not ret:
        print("Reached end of video or failed to read, exiting...")
        break  # Exit the loop if there are no frames to read

    # convert the image from NumPy array into a PIL image
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image = Image.fromarray(img)

    inputs = image_processor(images = image, return_tensors = "pt")
    outputs = model(**inputs)

    target_sizes = torch.tensor([image.size[::-1]])
    results = image_processor.post_process_object_detection(
        outputs, 
        target_sizes = target_sizes, 
        threshold = 0.25)[0]
    print(results)
    for score, label, box in zip(results["scores"], results["labels"], results["boxes"]):
        box = [round(i, 2) for i in box.tolist()]
        print(
            f"Detected {model.config.id2label[label.item()]} with confidence "
            f"{round(score.item(), 3)} at location {box}"        
        )

        # draw the bounding box
        cv2.rectangle(frame, 
                      (int(box[0]), int(box[1])),   # x1, y1
                      (int(box[2]), int(box[3])),   # x2, y2
                      yellow, 
                      stroke)
        
        # display the label
        cv2.putText(frame, 
                    model.config.id2label[label.item()], # label
                    (int(box[0]), int(box[1]-10)),       # x1, y1
                    font, 
                    1, 
                    yellow, 
                    stroke, 
                    cv2.LINE_AA)

    cv2.imshow('Video Playback', frame)  # Display the frame

    # Wait for 25 ms before moving on to the next frame
    # This will play the video at about 40 frames per second
    # Adjust the wait time as per your video's fps (use int(1000/fps))
    if cv2.waitKey(25) & 0xFF == ord('q'):
        print("Video playback interrupted by user.")
        break  # Exit the loop if 'q' is pressed
    key = cv2.waitKey(1) & 0xFF 
    if key == ord("q"):    # Press q to break out of the loop
        break

# Release the video capture object and close all OpenCV windows
cap.release()
cv2.waitKey(1)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# {'scores': tensor([0.3302], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2347.4832,  534.6648, 2556.5603,  857.0939]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.33 at location [2347.48, 534.66, 2556.56, 857.09]
# {'scores': tensor([0.3212], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2368.7734,  538.8475, 2556.7698,  863.0591]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.321 at location [2368.77, 538.85, 2556.77, 863.06]
# {'scores': tensor([0.3304], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2383.7166,  548.7296, 2557.0005,  882.5303]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.33 at location [2383.72, 548.73, 2557.0, 882.53]
# {'scores': tensor([0.3135, 0.3069], grad_fn=<IndexBackward0>), 'labels': tensor([1, 1]), 'boxes': tensor([[2398.6152,  593.3559, 2543.7952,  820.2440],
#         [2420.1313,  580.2976, 2557.9128,  897.8497]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.313 at location [2398.62, 593.36, 2543.8, 820.24]
# Detected license with confidence 0.307 at location [2420.13, 580.3, 2557.91, 897.85]
# {'scores': tensor([0.3113], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2434.8115,  576.5085, 2558.1694,  912.9265]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.311 at location [2434.81, 576.51, 2558.17, 912.93]
# {'scores': tensor([0.3035], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2454.9290,  590.8693, 2558.3352,  921.9568]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.304 at location [2454.93, 590.87, 2558.34, 921.96]
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([0.3078], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2307.0583,  583.5452, 2556.5742,  825.4924]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.308 at location [2307.06, 583.55, 2556.57, 825.49]
# {'scores': tensor([0.3037, 0.3246], grad_fn=<IndexBackward0>), 'labels': tensor([1, 1]), 'boxes': tensor([[2428.0417,  613.8558, 2515.7761,  673.3073],
#         [2326.7051,  588.6781, 2556.6313,  838.0693]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.304 at location [2428.04, 613.86, 2515.78, 673.31]
# Detected license with confidence 0.325 at location [2326.71, 588.68, 2556.63, 838.07]
# {'scores': tensor([0.3040, 0.3312], grad_fn=<IndexBackward0>), 'labels': tensor([1, 1]), 'boxes': tensor([[2448.2673,  627.4587, 2524.1660,  684.1917],
#         [2347.9009,  595.6244, 2556.7722,  855.5709]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.304 at location [2448.27, 627.46, 2524.17, 684.19]
# Detected license with confidence 0.331 at location [2347.9, 595.62, 2556.77, 855.57]
# {'scores': tensor([0.3213], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2360.8755,  608.5911, 2556.8765,  863.1343]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.321 at location [2360.88, 608.59, 2556.88, 863.13]
# {'scores': tensor([0.3332], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2384.7812,  624.3581, 2556.9304,  884.2476]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.333 at location [2384.78, 624.36, 2556.93, 884.25]
# {'scores': tensor([0.3399], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2409.9683,  631.9656, 2557.4500,  903.7686]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.34 at location [2409.97, 631.97, 2557.45, 903.77]
# {'scores': tensor([0.3094, 0.3115], grad_fn=<IndexBackward0>), 'labels': tensor([1, 1]), 'boxes': tensor([[2435.2803,  684.5172, 2557.9312,  908.0181],
#         [2438.3181,  647.7448, 2557.9209,  912.0422]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.309 at location [2435.28, 684.52, 2557.93, 908.02]
# Detected license with confidence 0.311 at location [2438.32, 647.74, 2557.92, 912.04]
# {'scores': tensor([0.3207], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2457.8374,  661.7552, 2558.4639,  895.3839]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.321 at location [2457.84, 661.76, 2558.46, 895.38]
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([0.3034], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2309.0151,  535.3296, 2533.5645,  759.6947]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.303 at location [2309.02, 535.33, 2533.56, 759.69]
# {'scores': tensor([0.3034], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2323.5852,  540.1887, 2534.4717,  769.8280]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.303 at location [2323.59, 540.19, 2534.47, 769.83]
# {'scores': tensor([0.3011, 0.3136, 0.3062], grad_fn=<IndexBackward0>), 'labels': tensor([1, 1, 1]), 'boxes': tensor([[2452.2886,  578.0119, 2516.3237,  631.9789],
#         [2334.5815,  540.8829, 2556.6558,  787.4172],
#         [2425.3496,  574.9427, 2511.6089,  632.0803]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.301 at location [2452.29, 578.01, 2516.32, 631.98]
# Detected license with confidence 0.314 at location [2334.58, 540.88, 2556.66, 787.42]
# Detected license with confidence 0.306 at location [2425.35, 574.94, 2511.61, 632.08]
# {'scores': tensor([0.3070, 0.3069], grad_fn=<IndexBackward0>), 'labels': tensor([1, 1]), 'boxes': tensor([[2350.1560,  573.7794, 2556.8096,  798.6228],
#         [2447.9072,  585.0325, 2527.1284,  643.8138]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.307 at location [2350.16, 573.78, 2556.81, 798.62]
# Detected license with confidence 0.307 at location [2447.91, 585.03, 2527.13, 643.81]
# {'scores': tensor([0.3248], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2363.1897,  557.3137, 2557.0090,  815.2572]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.325 at location [2363.19, 557.31, 2557.01, 815.26]
# {'scores': tensor([0.3131], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2382.8018,  597.0773, 2542.2410,  823.5031]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.313 at location [2382.8, 597.08, 2542.24, 823.5]
# {'scores': tensor([0.3301], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2401.3708,  582.2123, 2556.6523,  836.1156]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.33 at location [2401.37, 582.21, 2556.65, 836.12]
# {'scores': tensor([0.3347], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2411.2371,  595.3278, 2557.4299,  851.6700]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.335 at location [2411.24, 595.33, 2557.43, 851.67]
# {'scores': tensor([0.3097], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2446.7439,  601.3533, 2558.1313,  881.7405]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.31 at location [2446.74, 601.35, 2558.13, 881.74]
# {'scores': tensor([0.3090, 0.3081], grad_fn=<IndexBackward0>), 'labels': tensor([1, 1]), 'boxes': tensor([[2453.0466,  613.1599, 2558.0938,  872.1979],
#         [2449.7153,  663.3304, 2550.7109,  855.7921]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.309 at location [2453.05, 613.16, 2558.09, 872.2]
# Detected license with confidence 0.308 at location [2449.72, 663.33, 2550.71, 855.79]
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([0.3163], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2404.2012,  432.3739, 2511.9429,  523.4366]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.316 at location [2404.2, 432.37, 2511.94, 523.44]
# {'scores': tensor([0.3020, 0.3199], grad_fn=<IndexBackward0>), 'labels': tensor([1, 1]), 'boxes': tensor([[2444.5598,  452.0896, 2515.9194,  516.7769],
#         [2438.5615,  443.0269, 2542.1677,  538.6273]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.302 at location [2444.56, 452.09, 2515.92, 516.78]
# Detected license with confidence 0.32 at location [2438.56, 443.03, 2542.17, 538.63]
# {'scores': tensor([0.3081, 0.3016, 0.3062], grad_fn=<IndexBackward0>), 'labels': tensor([1, 1, 1]), 'boxes': tensor([[2446.5332,  466.3154, 2518.7034,  541.1812],
#         [2448.8662,  463.8534, 2519.3169,  535.8169],
#         [2443.0913,  453.7345, 2541.8994,  548.4854]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.308 at location [2446.53, 466.32, 2518.7, 541.18]
# Detected license with confidence 0.302 at location [2448.87, 463.85, 2519.32, 535.82]
# Detected license with confidence 0.306 at location [2443.09, 453.73, 2541.9, 548.49]
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([0.3102], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2390.7869,  483.1689, 2507.0457,  571.4538]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.31 at location [2390.79, 483.17, 2507.05, 571.45]
# {'scores': tensor([0.3233], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2408.1177,  487.0190, 2538.1489,  584.6725]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.323 at location [2408.12, 487.02, 2538.15, 584.67]
# {'scores': tensor([0.3115], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2438.9021,  503.9803, 2535.3904,  587.1985]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.312 at location [2438.9, 503.98, 2535.39, 587.2]
# {'scores': tensor([0.3078], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2446.0183,  516.5987, 2538.8862,  600.7225]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.308 at location [2446.02, 516.6, 2538.89, 600.72]
# {'scores': tensor([0.3058], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[2454.5249,  527.8137, 2546.6562,  627.9643]],
#        grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.306 at location [2454.52, 527.81, 2546.66, 627.96]
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([0.3111], grad_fn=<IndexBackward0>), 'labels': tensor([1]), 'boxes': tensor([[ 46.0096, 635.9986, 429.5838, 930.8868]], grad_fn=<IndexBackward0>)}
# Detected license with confidence 0.311 at location [46.01, 636.0, 429.58, 930.89]
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
# {'scores': tensor([], grad_fn=<IndexBackward0>), 'labels': tensor([], dtype=torch.int64), 'boxes': tensor([], size=(0, 4), grad_fn=<IndexBackward0>)}
